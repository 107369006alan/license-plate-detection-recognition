# %%
#detect & recognise the car plate from an image
from yolo import YOLO
from recogniser import Plate_Recogniser
from PIL import Image
import cv2
import sys
import argparse
import numpy as np
import matplotlib.pyplot as plt

# %%
detector = YOLO()
recogniser = Plate_Recogniser()
# Out:
# model_data/plate_detect.h5 model, anchors, and classes loaded.

# %%
image_path = './test.jpg'
image = Image.open(image_path)
plt.imshow(image)

# %%
out_boxes, out_scores, out_classes = detector.detect_image(image)
out_boxes = out_boxes.astype('int')
ymin, xmin, ymax, xmax = out_boxes[0]

# %%
plate = np.asarray(image)[ymin:ymax, xmin:xmax]
plt.imshow(plate)

# %%
text = recogniser.plate_recognise(plate)
print(text)
# Out:
# FE879S
